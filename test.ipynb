# %%
import numpy as np
import scipy
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
data1= 100 * np.random.random(100)
data2 = data1 + 10 + np.random.random(100)
data3 = 100 * np.random.random(100)
data4 = data2 + data3 + np.random.random(100) - 8

d = np.vstack([data1, data2, data3, data4]).T

# %%
df = pd.DataFrame(d, columns=['data1', 'data2', 'data3', 'data4'])
df
# Out:
#         data1       data2      data3       data4
# 0   57.826256   68.021862  79.386688  139.792262
# 1    6.742906   17.188404  29.496133   39.420485
# 2   10.449083   21.291125  10.405832   23.795802
# 3   62.865707   73.055679  80.295307  146.016305
# 4   86.400454   96.427883  60.865098  149.330694
# ..        ...         ...        ...         ...
# 95   7.146863   17.446739  86.395574   96.398815
# 96   0.471958   10.503407   7.501580   10.680735
# 97  52.189006   62.262033   7.095198   62.304529
# 98  96.784661  107.740376  20.416337  120.285999
# 99  15.205640   25.462204  31.461275   49.651733
#
# [100 rows x 4 columns]

# %%
Z = scipy.cluster.hierarchy.linkage(df.corr(), 'single', 'correlation')

fig, ax = plt.subplots(figsize=(10, 10))
scipy.cluster.hierarchy.dendrogram(Z, color_threshold=0);

# %%
import seaborn as sns
from scipy.cluster.hierarchy import dendrogram
from scipy.spatial.distance import pdist, squareform

D = squareform(pdist(d.T, 'correlation'))
h = sns.clustermap(D, cmap='Reds')
# Out:
# C:\Users\bugae\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\matrix.py:530: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage = hierarchy.linkage(self.array, method=self.method,
# C:\Users\bugae\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\matrix.py:530: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage = hierarchy.linkage(self.array, method=self.method,

# %%
Z = h.dendrogram_col.linkage    
dendrogram(Z, color_threshold=0)
# Out:
# {'icoord': [[25.0, 25.0, 35.0, 35.0],
#   [15.0, 15.0, 30.0, 30.0],
#   [5.0, 5.0, 22.5, 22.5]],
#  'dcoord': [[0.0, 0.38887528990077647, 0.38887528990077647, 0.0],
#   [0.0, 0.7958275992803383, 0.7958275992803383, 0.38887528990077647],
#   [0.0, 1.5356510298658896, 1.5356510298658896, 0.7958275992803383]],
#  'ivl': ['2', '3', '0', '1'],
#  'leaves': [2, 3, 0, 1],
#  'color_list': ['C0', 'C0', 'C0'],
#  'leaves_color_list': ['C0', 'C0', 'C0', 'C0']}

# %%
sns.clustermap(df.corr(), method="complete", cmap='RdBu', annot=True, vmin=-1, vmax=1);
